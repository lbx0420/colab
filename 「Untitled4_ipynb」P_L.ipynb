# %% [markdown]
# <a href="https://colab.research.google.com/github/lbx0420/colab/blob/main/%E3%80%8CUntitled4_ipynb%E3%80%8DP_L.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import nltk
nltk.download('popular')
nltk.download('all-corpora')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# ...

# %%
import nltk
from nltk.corpus import PlaintextCorpusReader
corpus_root = '/content/drive/MyDrive/colab language' # 請改成自己的路徑 File Path
wordlists = PlaintextCorpusReader(corpus_root, '.*', encoding = 'latin-1') # .* => find all files, .txt => only find txt files

books = wordlists.fileids()
print(books)
# Out:
# ['2soon.txt', 'besides you.txt', 'blue.txt']

# %%
import nltk
testText = wordlists.words('2soon.txt')
single = nltk.text.Text(testText)
print(single)
# Out:
# <Text: Drank too much , got the sickness Pray...>

# %%
# 文章中字詞出現次數
single.count("drank")
# Out:
# 0

# %%
# 搜尋字詞功能
single.concordance("people", lines=100)
# Out:
# no matches

# %%
# 關聯字
single.similar("drank")

# %%
#list
context = ["you","the", "drank"]

single.common_contexts(context)
# Out:
# No common contexts were found

# %%
text = wordlists.words('2soon.txt')
print(text)
print(len(text))
# Out:
# ['Drank', 'too', 'much', ',', 'got', 'the', 'sickness', ...]
# 498

# %%
from nltk.tokenize import word_tokenize
dataset = wordlists.raw('2soon.txt')
print(word_tokenize(dataset))
print(len(word_tokenize(dataset)))
# Out:
# ['Drank', 'too', 'much', ',', 'got', 'the', 'sickness', 'Pray', 'to', 'God', 'and', 'his', 'son', 'for', 'forgiveness', 'Same', 'crew', 'but', 'another', 'mistress', 'Every', 'day', ',', 'every', 'night', 'getting', 'wasted', 'But', 'I', 'miss', 'you', ',', 'what', 'did', 'I', 'do', '?', 'Fuck', 'it', 'up', ',', 'laugh', 'it', 'off', ',', 'and', 'I', 'lost', 'you', 'If', 'I', 'pull', 'through', ',', 'is', 'it', 'too', 'soon', '?', 'Turn', 'it', 'up', ',', 'close', 'my', 'eyes', ',', 'then', 'I', "'m", 'with', 'you', 'Yo', 'Marvin', ',', 'stop', "callin'", 'Sad', 'Iverson', 'is', "ballin'", 'In', 'the', 'corner', 'of', 'a', 'room', 'by', 'himself', 'You', 'are', 'nothin', "'", 'but', 'an', 'empty', 'shell', 'Every', 'night', ',', 'he', 'going', 'down', 'to', 'hell', 'Fake', 'love', 'in', 'a', 'shit', 'hotel', 'Ca', "n't", 'believe', 'how', 'far', 'he', 'fell', 'You', 'weak', 'on', 'the', 'floor', 'so', 'you', 'call', 'her', 'cell', "''", 'How', 'you', 'been', '?', '``', ',', '``', 'Ho
# ...

# %%
from nltk.tokenize import sent_tokenize
dataset = wordlists.raw('2soon.txt')
print(sent_tokenize(dataset))
print(len(sent_tokenize(dataset)))
# Out:
# ['Drank too much, got the sickness\rPray to God and his son for forgiveness\rSame crew but another mistress\rEvery day, every night getting wasted\rBut I miss you, what did I do?', 'Fuck it up, laugh it off, and I lost you\rIf I pull through, is it too soon?', 'Turn it up, close my eyes, then I\'m with you\rYo Marvin, stop callin\'\rSad Iverson is ballin\'\rIn the corner of a room by himself\rYou are nothin\' but an empty shell\rEvery night, he going down to hell\rFake love in a shit hotel\rCan\'t believe how far he fell\rYou weak on the floor so you call her cell\r"How you been?', '", "How you doing?"', "You been good, I been drinking\rWay too much, you think that I'd be over you, over you, over you\r(Eight calls, all you)\rBut I think about it every day, yeah\rYeah, I never missed her anyways\rYeah, I never missed her anyways\rDrank too much, got the sickness\rPray to God and his son for forgiveness\rSame crew but another mistress\rEvery day, every night getting wasted\rBut I miss 
# ...

# %%
text = wordlists.words('2soon.txt')
# 相異字詞
set(text)

# 相異字詞排序
tempText = sorted(set(text))
print(tempText)

# 定義詞彙多樣性的函數
def difference(text):
    result = len(set(text)) / len(text)
    return result

print(difference(text))
# Out:
# ['"', "'", '(', ')', ',', '-', '?', '?"', '?",', 'But', 'Call', 'Can', 'Don', 'Drank', 'Eight', 'Every', 'Fake', 'Fuck', 'God', 'How', 'I', 'If', 'In', 'Iverson', 'Marvin', 'No', 'Pray', 'Sad', 'Same', 'Stay', 'The', 'Tonight', 'Turn', 'Way', 'Yeah', 'Yo', 'You', 'a', 'about', 'alcohol', 'all', 'an', 'and', 'another', 'anyways', 'are', 'ball', 'ballin', 'be', 'been', 'believe', 'but', 'by', 'call', 'callin', 'calls', 'cell', 'close', 'corner', 'crew', 'cried', 'd', 'day', 'did', 'do', 'doing', 'don', 'down', 'drinking', 'eight', 'empty', 'enough', 'every', 'eyes', 'far', 'fell', 'floor', 'for', 'forgiveness', 'frostbite', 'fucks', 'get', 'getting', 'going', 'good', 'got', 'guy', 'he', 'hell', 'her', 'hide', 'himself', 'his', 'hotel', 'how', 'if', 'in', 'is', 'it', 'laugh', 'll', 'lost', 'love', 'm', 'ma', 'matter', 'me', 'member', 'miss', 'missed', 'mistress', 'much', 'my', 'never', 'night', 'not', 'nothin', 'of', 'off', 'on', 'other', 'over', 'pride', 'pull', 'room', 'shell', 'shit'
# ...

# %%
import nltk
testText = wordlists.words('2soon.txt')
single = nltk.text.Text(testText)

findList = ["every","you", "i", "drank", "night"]
single.dispersion_plot(findList)

# %%
# 使用 ConditionalFreqDist() 在多個文本中計算特定字詞個數

books = wordlists.fileids()
cfd = nltk.ConditionalFreqDist((fileid, word)
    for fileid in books
    for word in wordlists.words(fileid)
    )
findList = ['can', 'could', 'may', 'might', 'must', 'will', 'shall', 'should']
cfd.tabulate(conditions=books, samples=findList)
# Out:
#                    can  could    may  might   must   will  shall should
#       2soon.txt      0      0      0      0      0      0      0      0
# besides you.txt      5      0      0      0      0      0      0      0
#        blue.txt      0      0      0      0      0      0      0      0

# %%
books = wordlists.fileids()
print(books)
# Out:
# ['2soon.txt', 'besides you.txt', 'blue.txt']

# %%
cfd = nltk.ConditionalFreqDist(
    (target, fileid[:7]) # [:7]取至前七位字元
    for fileid in wordlists.fileids() # 取出各個文檔
    for w in wordlists.words(fileid)  # 所有文本的字詞
    for target in ['happy', 'positive', 'negative'] # 篩選字詞
    if w.lower() == target) # w.lower().startswith(target)  # 字詞 happier也能納入計算
cfd.plot()
# Out:
# <Axes: >

# %%
from wordcloud import STOPWORDS
print(STOPWORDS)
# Out:
# {'until', 'it', "it's", 'an', 'up', 'off', "she's", "weren't", 'between', "what's", 'down', 'further', "they've", 'com', 'has', 'himself', 'themselves', 'does', 'into', 'you', "doesn't", 'had', 'nor', 'with', 'were', 'how', "shan't", 'her', 'have', 'here', 'since', 'on', 'why', 'than', 'me', 'else', 'them', 'he', "they'd", 'then', 'their', 'was', "i'll", "didn't", 'such', "they'll", 'not', 'before', 'whom', 'after', 'below', 'having', 'at', 'those', 'my', 'his', 'be', "that's", "you're", 'get', "don't", "hadn't", 'ourselves', 'in', 'http', 'therefore', 'otherwise', 'but', 'each', 'this', 'she', 'no', 'if', "wouldn't", 'being', 'also', 'few', 'been', "wasn't", 'for', 'where', 'doing', 'yourself', 'i', 'do', 'very', 'to', 'that', "let's", "we'll", 'there', "i'd", "here's", "where's", 'against', 'because', "who's", 'during', 'when', "can't", 'or', "couldn't", "aren't", 'ought', "they're", 'over', 'www', "he'll", "how's", 'herself', "he's", 'ours', 'once', 'same', 'its', 'did', 'and', 'a
# ...

# %%
#分析高頻率單字

import nltk
from wordcloud import STOPWORDS

dataset = wordlists.raw('2soon.txt')

tokens = dataset.split(' ')
clean_tokens = tokens[:]

for token in tokens:
  if token.lower() in STOPWORDS:
    clean_tokens.remove(token)

freq = nltk.FreqDist(clean_tokens)

# for key,val in freq.items():
#  print (str(key) + ':' + str(val))
freq.plot(20,cumulative=False)
# Out:
# ) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ls '/content/drive/MyDrive/Colab Notebooks/TED'
# Out:
# ls: cannot access '/content/drive/MyDrive/Colab Notebooks/TED': No such file or directory

# %%
import nltk
nltk.download("popular")
nltk.download('all-corpora')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to /root/nltk_data...
# ...

# %%
import nltk

from nltk.corpus import PlaintextCorpusReader

corpus_root = '/content/drive/My Drive/colab language' # 請改成自己的路徑
wordlists = PlaintextCorpusReader(corpus_root, '.*') # *: all .txt

books = wordlists.fileids()
print(books)
# Out:
# ['2soon.txt', 'besides you.txt', 'blue.txt']

# %%
from nltk.corpus import brown
# 使用 ConditionalFreqDist() 在多個文本中計算特定字詞個數


cfd = nltk.ConditionalFreqDist((fileid, word)
    for fileid in books
    for word in wordlists.words(fileid)
    )

findList = ['you', 'i', 'drank']
cfd.tabulate(conditions=books, samples=findList)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-23-8fcf8d21f7af> in <cell line: 5>()
#       3
#       4
# ----> 5 cfd = nltk.ConditionalFreqDist((fileid, word)
#       6     for fileid in books
#       7     for word in wordlists.words(fileid)
#
# /usr/local/lib/python3.10/dist-packages/nltk/probability.py in __init__(self, cond_samples)
#    1892
#    1893         if cond_samples:
# -> 1894             for (cond, sample) in cond_samples:
#    1895                 self[cond][sample] += 1
#    1896
#
# <ipython-input-23-8fcf8d21f7af> in <genexpr>(.0)
#       3
#       4
# ----> 5 cfd = nltk.ConditionalFreqDist((fileid, word)
#       6     for fileid in books
#       7     for word in wordlists.words(fileid)
#
# /usr/local/lib/python3.10/dist-packages/nltk/corpus/reader/util.py in iterate_from(self, start_tok)
#     304             self._current_toknum = toknum
# ...

# %%
#分析高頻率單字

import nltk
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.probability import FreqDist
from nltk.corpus import stopwords
import string

dataset = wordlists.raw('2soon.txt') # your txt file
text_list = dataset.split()

stop = stopwords.words('english')
wnl = WordNetLemmatizer()

# 去掉停用
clean_tokens = text_list[:]
for token in text_list:
  if token.lower() in stopwords.words('english'):
    clean_tokens.remove(token)


# 去掉標點
no_string_tokens = clean_tokens
for token in clean_tokens:
  if token in string.punctuation or token in '--' or token in '?': # ? !..
    no_string_tokens.remove(token)

# 轉成小寫, 去掉空格
lower_tokens = []
for token in no_string_tokens:
  new_token = token.replace(' ', '');
  lower_tokens.append(new_token.lower())

# 詞性還原
lemmatizer_tokens = []
for token in lower_tokens:
 lemmatizer_tokens.append(wnl.lemmatize(token))


fdist = FreqDist(lemmatizer_tokens)
#出現頻率最高的10個單字
fdist1 = fdist.most_common(10)
print(fdist1)
# Out:
# [('every', 10), ('up,', 8), ('you,', 7), ('fuck', 6), ('much,', 5), ('day,', 5), ('drank', 4), ('got', 4), ('sickness', 4), ('pray', 4)]

# %%
import matplotlib.pyplot as plt

x = [data[0] for data in fdist1] # ['people', 'older', 'life' ...]
y = [data[1] for data in fdist1] # ['29', '19', '12' ...]

plt.bar(x, y)     #繪製長條圖
plt.title('Key words')          #設定圖形標題
plt.xlabel('Words')                #設定X軸標籤
plt.ylabel('Nums')                   #設定Y軸標籤
plt.xticks(fontsize=10, rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt

x = ['happy', 'positive', 'trouble', 'refactor']
y = [20, 15, 26, 10]


plt.bar(x, y)     #繪製長條圖
plt.title('Key words')          #設定圖形標題
plt.xlabel('Words')                #設定X軸標籤
plt.ylabel('Nums')                   #設定Y軸標籤
plt.figure(figsize=(5,4))
plt.show()

# %%
findList = ['you', 'i', 'drank' ]

for fileid in books:
   myWords = wordlists.words(fileid)
   myText = nltk.text.Text(myWords)
   print(fileid)
   myText.dispersion_plot(findList)

# %%
cfd = nltk.ConditionalFreqDist(
           (target, fileid[:7]) # 表格下方顯示txt檔名前七個字
           for fileid in wordlists.fileids()
           for w in wordlists.words(fileid)
           #List裡面請改成你要搜尋的字詞
           for target in ['i', 'you', 'drank', 'lie']
           if w.lower().startswith(target))
cfd.plot()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-35-6216aa41a0aa> in <cell line: 1>()
# ----> 1 cfd = nltk.ConditionalFreqDist(
#       2            (target, fileid[:7]) # 表格下方顯示txt檔名前七個字
#       3            for fileid in wordlists.fileids()
#       4            for w in wordlists.words(fileid)
#       5            #List裡面請改成你要搜尋的字詞
#
# /usr/local/lib/python3.10/dist-packages/nltk/probability.py in __init__(self, cond_samples)
#    1892
#    1893         if cond_samples:
# -> 1894             for (cond, sample) in cond_samples:
#    1895                 self[cond][sample] += 1
#    1896
#
# <ipython-input-35-6216aa41a0aa> in <genexpr>(.0)
# ----> 1 cfd = nltk.ConditionalFreqDist(
#       2            (target, fileid[:7]) # 表格下方顯示txt檔名前七個字
#       3            for fileid in wordlists.fileids()
#       4            for w in wordlists.words(fileid)
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# doc: https://amueller.github.io/word_cloud/generated/wordcloud.WordCloud.html

#讀取文本
file_text = open('/content/drive/MyDrive/colab language/2soon.text','r').read()


# background_color 背景顏色
# width 寬
# height 高
# margin 圖片邊緣
# max_font_size 設定文字中最大的大小是多少
# min_font_size
# max_words  文字雲顯示最大詞數
# font_path="/tmp/DFFT_C7.ttc", #設置字體

wordcloud = WordCloud(
    background_color="white",
    width=2000,
    height=1000,
    margin= 10,
).generate(file_text)


plt.imshow(wordcloud)
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-30-d104e8e4c62d> in <cell line: 7>()
#       5
#       6 #讀取文本
# ----> 7 file_text = open('/content/drive/MyDrive/colab language/2soon.text','r').read()
#       8
#       9
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/colab language/2soon.text'

# %%
from wordcloud import STOPWORDS
print(STOPWORDS)
# Out:
# {'until', 'it', "it's", 'an', 'up', 'off', "she's", "weren't", 'between', "what's", 'down', 'further', "they've", 'com', 'has', 'himself', 'themselves', 'does', 'into', 'you', "doesn't", 'had', 'nor', 'with', 'were', 'how', "shan't", 'her', 'have', 'here', 'since', 'on', 'why', 'than', 'me', 'else', 'them', 'he', "they'd", 'then', 'their', 'was', "i'll", "didn't", 'such', "they'll", 'not', 'before', 'whom', 'after', 'below', 'having', 'at', 'those', 'my', 'his', 'be', "that's", "you're", 'get', "don't", "hadn't", 'ourselves', 'in', 'http', 'therefore', 'otherwise', 'but', 'each', 'this', 'she', 'no', 'if', "wouldn't", 'being', 'also', 'few', 'been', "wasn't", 'for', 'where', 'doing', 'yourself', 'i', 'do', 'very', 'to', 'that', "let's", "we'll", 'there', "i'd", "here's", "where's", 'against', 'because', "who's", 'during', 'when', "can't", 'or', "couldn't", "aren't", 'ought', "they're", 'over', 'www', "he'll", "how's", 'herself', "he's", 'ours', 'once', 'same', 'its', 'did', 'and', 'a
# ...

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

#讀取文本
f = open('/content/drive/MyDrive/colab language/2soon.txt','r').read()

# stopwords 停用字詞
stop = ["people", "old people", "time", "life"] + list(STOPWORDS)

wordcloud = WordCloud(
    background_color="white",
    width=1500,
    height=1000,
    margin=2,
    stopwords=stop
).generate(f)


plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
import nltk

from nltk.corpus import PlaintextCorpusReader

corpus_root = '/content/drive/My Drive/colab language' # 請改成自己的路徑
wordlists = PlaintextCorpusReader(corpus_root, '.*')

books = wordlists.fileids()
print(books)
# Out:
# ['2soon.txt', 'besides you.txt', 'blue.txt']

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt


stop = list(STOPWORDS)

for fileid in books:
  f = open('/content/drive/My Drive/colab language'+fileid,'r').read()
  wordcloud = WordCloud(
      background_color="white",
      width=1500,
      height=1200,
      margin=2,
      stopwords=stop
  ).generate(f)

  plt.imshow(wordcloud)
  plt.axis("off")
  print(fileid)
  plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-34-b1385a7a8513> in <cell line: 7>()
#       6
#       7 for fileid in books:
# ----> 8   f = open('/content/drive/My Drive/colab language'+fileid,'r').read()
#       9   wordcloud = WordCloud(
#      10       background_color="white",
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/colab language2soon.txt'
